# %% [markdown]
# # Group Members:
#      - Mayibongwe Bafoly - 1611957
#      - Phutinane Donald Chipu - 2172765
#      - O'neil Sithole - 1894057
#      - Thabelang Ncube - 1918469

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
dataFrame = pd.read_csv("DataSet.csv")
dataFrame
# Out:
#               Country  TotalArea   LandArea  WaterArea  \
# 0              Tuvalu       26.0       26.0        0.0
# 1    Marshall Islands      181.0      181.0    11673.0
# 2             Bahamas    13943.0    10010.0     3870.0
# 3              Gambia    11295.0    10000.0     1295.0
# 4               Nauru       21.0       21.0        0.0
# ..                ...        ...        ...        ...
# 167            Bhutan    38394.0    38394.0        0.0
# 168             India  3287263.0  2973190.0   314073.0
# 169          Pakistan   881913.0   856690.0    25223.0
# 170             Nepal   147516.0   143686.0     3830.0
# 171     United States  9833517.0  9147593.0   685924.0
#
#                       HighestPoint  MaximumElevation              LowestPoint  \
# 0    Unnamed location on Niulakita               5.0      South Pacific Ocean
# 1       Unnamed location on Likiep              10.0      North Pacific Ocean
# ...

# %%
# %matplotlib inline
plt.xlabel('TotalArea')
plt.ylabel('Maximum.elevation')
plt.scatter(dataFrame.TotalArea,dataFrame.MaximumElevation, color='green',marker='*')
plt.show()

# %%
linearRegressionObject = linear_model.LinearRegression()
linearRegressionObject.fit(dataFrame[['TotalArea']],dataFrame.MaximumElevation)
# Out:
# LinearRegression()

# %%
# %matplotlib inline
plt.xlabel('MinimumElevation')
plt.ylabel('Maximum.elevation')
plt.scatter(dataFrame.MinimumElevation,dataFrame.MaximumElevation, color='green',marker='*')
plt.show()

# %%
linearRegressionObject1 =  linear_model.LinearRegression()
linearRegressionObject1.fit(dataFrame[['MinimumElevation']],dataFrame.MaximumElevation)
# Out:
# LinearRegression()
